# %% [markdown]
# # HW04 Colab Setup
#
# Run the cells below in order. They mount Google Drive when running in Colab, switch into the `HW04` project directory, install the notebook dependencies into the current kernel, and verify that the spaCy models can be loaded.

# %%
import os, sys, torch

print("python:", sys.executable)
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("COLAB_GPU:", os.environ.get("COLAB_GPU"))
# !nvidia-smi

# %%
import torch
print(torch.cuda.is_available())

# %%
from pathlib import Path
import os
import sys

IN_COLAB = False
try:
    from google.colab import drive  # type: ignore
    IN_COLAB = True
except ImportError:
    drive = None

if IN_COLAB:
    drive.mount('/content/drive')
    project_root = Path('/content/drive/Othercomputers/我的笔记本电脑/GitHub/PKU-AI-Fundamentals-2026-Spring/Homework/HW04')
    if not project_root.exists():
        raise FileNotFoundError(f'Cannot find project directory: {project_root}')
    os.chdir(project_root)
else:
    project_root = Path.cwd()

print('project_root =', project_root)
print('python =', sys.version)
print('python exe =', sys.executable)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# project_root = /content/drive/Othercomputers/我的笔记本电脑/GitHub/PKU-AI-Fundamentals-2026-Spring/Homework/HW04
# python = 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# python exe = /usr/bin/python3

# %%
# %pip install -U pip setuptools wheel
# %pip install "numpy<2" "spacy==3.8.14" "spacy-pkuseg>=1.0.0" tqdm

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy download de_core_news_sm
# !python -m spacy download zh_core_web_sm

# %%
import spacy
import torch

for model_name in ['en_core_web_sm', 'de_core_news_sm', 'zh_core_web_sm']:
    spacy.load(model_name)
    print('loaded', model_name)

print('torch =', torch.__version__)
print('cuda available =', torch.cuda.is_available())
print('current cwd =', Path.cwd())

# %% [markdown]
# ## Next Steps
#
# - `nmt_de2en.py` can create `.data/Multi30k` automatically if it is missing.
# - `nmt_zh2en.py` still requires `.data/NEWS-Commentary/news_zh.txt` and `.data/NEWS-Commentary/news_en.txt` to exist.
# - Typical training commands in Colab:
#   - `!python nmt_de2en.py`
#   - `!python nmt_zh2en.py`
